# %% [markdown]
# # Basic Models

# %% [markdown]
# Introduction to basic models for data analysis

# %%
#import some packages
import pandas as pd
#use statsmodels for stats testing & modeling
import statsmodels.api as sm

from __future__ import division
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
import os
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#read in data
df = pd.read_csv("GSS.2006.csv.xls")
df.head()
# Out:
#    vpsu  vstrat  adults  ballot  dateintv  famgen  form  formwt  gender1  \
# 0     1    1957       1       3       316       2     1       1        2
# 1     1    1957       2       2       630       1     2       1        2
# 2     1    1957       2       2       314       2     1       1        2
# 3     1    1957       1       1       313       1     2       1        2
# 4     1    1957       3       1       322       2     2       1        2
#
#    hompop  ...  away7  gender14  old14  relate14  relhh14  relhhd14  relsp14  \
# 0       3  ...    NaN       NaN    NaN       NaN      NaN       NaN      NaN
# 1       2  ...    NaN       NaN    NaN       NaN      NaN       NaN      NaN
# 2       2  ...    NaN       NaN    NaN       NaN      NaN       NaN      NaN
# 3       1  ...    NaN       NaN    NaN       NaN      NaN       NaN      NaN
# 4       3  ...    NaN       NaN    NaN       NaN      NaN       NaN      NaN
#
#    where12  where6  where7
# 0      NaN     NaN     NaN
# ...

# %% [markdown]
# ### Dealing with Missing Data

# %%
#find missing data
df[df.isna().any('columns')]
# Out:
#       vpsu  vstrat  adults  ballot  dateintv  famgen  form  formwt  gender1  \
# 0        1    1957       1       3       316       2     1       1        2
# 1        1    1957       2       2       630       1     2       1        2
# 2        1    1957       2       2       314       2     1       1        2
# 3        1    1957       1       1       313       1     2       1        2
# 4        1    1957       3       1       322       2     2       1        2
# ...    ...     ...     ...     ...       ...     ...   ...     ...      ...
# 4505     1    2092       1       2       803       2     1       1        1
# 4506     2    2092       1       2       629       1     1       1        2
# 4507     2    2092       2       4       709       2     1       1        2
# 4508     2    2092       2       2       706       2     1       1        2
# 4509     1    2093       1       2       627       1     2       1        1
#
# ...

# %%
#can also look visually
sns.heatmap(data=df.isna(), cmap='plasma')
# Out:
# <AxesSubplot:>

# %%
#different methods of filling this data / imputing
df.fillna(method='ffill')

#we can also use method = 'bfill' and .interpolate to fill in missing data
# Out:
#       vpsu  vstrat  adults  ballot  dateintv  famgen  form  formwt  gender1  \
# 0        1    1957       1       3       316       2     1       1        2
# 1        1    1957       2       2       630       1     2       1        2
# 2        1    1957       2       2       314       2     1       1        2
# 3        1    1957       1       1       313       1     2       1        2
# 4        1    1957       3       1       322       2     2       1        2
# ...    ...     ...     ...     ...       ...     ...   ...     ...      ...
# 4505     1    2092       1       2       803       2     1       1        1
# 4506     2    2092       1       2       629       1     1       1        2
# 4507     2    2092       2       4       709       2     1       1        2
# 4508     2    2092       2       2       706       2     1       1        2
# 4509     1    2093       1       2       627       1     2       1        1
#
# ...

# %% [markdown]
# ### Recoding Data

# %% [markdown]
# Sometimes our data is not in a format that is easy to work with and we need to recode it

# %%
# map indicator variables - we map them to make the numbers strings
df['degree'].replace({0: 'Lt High School', 1: 'High School', 2:'Junior College', 3: 'Bachelor', 4:'Graduate'}\
                         , inplace=True)

# we can create a crosstab to see our updated data & get percentages

#define comp_pct function
def comp_pct(x):
      pct = float(x / tab['count'].sum()) * 100
      return round(pct, 2)


tab = pd.crosstab(index=df["degree"],  # Make a crosstab
                              columns="count")     

tab['percentage'] = tab.apply(comp_pct, axis=1)

tab
# Out:
# col_0           count  percentage
# degree
# Bachelor          763       16.93
# Graduate          403        8.94
# High School      2273       50.43
# Junior College    377        8.36
# Lt High School    691       15.33

# %%
# we can also put a continuous variable into bins, using different cutoffs

def binning(col, cut_points, labels=None):
  #Define min and max values:
  minval = col.min()
  maxval = col.max()

  #create list by adding min and max to cut_points
  break_points = [minval] + cut_points + [maxval]

  #if no labels provided, use default labels 0 ... (n-1)
  if not labels:
    labels = range(len(cut_points)+1)

  #Binning using cut function of pandas
  colBin = pd.cut(col,bins=break_points,labels=labels,include_lowest=True)
  return colBin

#Binning attend:

cut_points = [1, 2, 4, 7]
labels = ["small_family","medium_family","van_family","large_family", "xl_family"]
df["sibs_cut"] = binning(df["sibs"], cut_points, labels)

# %%
#look at our new bins

tab_sibs = pd.crosstab(index=df["sibs_cut"], columns="count")     
tab_sibs['percentage'] = tab_sibs.apply(comp_pct, axis=1)

tab_sibs
# Out:
# col_0          count  percentage
# sibs_cut
# small_family     705       15.64
# medium_family    605       13.42
# van_family       784       17.40
# large_family     564       12.51
# xl_family        330        7.32

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# Simple linear regressions to find relationships. More complex models require more thought - but you can easily apply other types of models within the statsmodel package in a similar fashion.

# %%
#define your variables
x = df.population
y = df.total_households

# %%
#give your model a constant
x = sm.add_constant(x)

# %%
#OLS Model
model = sm.OLS(y, x)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:       total_households   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.996
# Method:                 Least Squares   F-statistic:                 2.607e+05
# Date:                Wed, 16 Feb 2022   Prob (F-statistic):               0.00
# Time:                        15:54:31   Log-Likelihood:                -10522.
# No. Observations:                 917   AIC:                         2.105e+04
# Df Residuals:                     915   BIC:                         2.106e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4944.8578    802.554      6.161      0.000    3369.797    6519.918
# ...

# %% [markdown]
# ### Logistic Regression
